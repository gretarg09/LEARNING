# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import scipy.stats as stats
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# !pip install jupyterlab-vim
# Out:
# Collecting jupyterlab-vim
#   Downloading jupyterlab_vim-4.0.3-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 1.0 MB/s eta 0:00:011
# Requirement already satisfied: jupyterlab<5,>=4.0.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab-vim) (4.0.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.7.3)
# Requirement already satisfied: tornado>=6.2.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (6.3.3)
# Requirement already satisfied: packaging in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (23.1)
# Requirement already satisfied: jupyter-core in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (5.3.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.19.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.24.0)
# Requirement already satisfied: tomli in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.0.1)
# Requirement already satisfied: notebook-shim>=0.2 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.2.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.2.0)
# Requirement already satisfied: ipykernel in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (6.25.2)
# Requirement already satisfied: async-lru>=1.0.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.0.4)
# Requirement already satisfied: traitlets in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (5.9.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.0->jupyterlab-vim) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (4.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.1.3)
# Requirement already satisfied: jupyter-server-terminals in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (7.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.17.1)
# Requirement already satisfied: websocket-client in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.6.2)
# Requirement already satisfied: nbformat>=5.3.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (5.9.2)
# Requirement already satisfied: prometheus-client in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.17.1)
# Requirement already satisfied: overrides in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (7.4.0)
# Requirement already satisfied: argon2-cffi in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (23.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.8.2)
# Requirement already satisfied: pyzmq>=24 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (25.1.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (4.0.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (8.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.1.3)
# Requirement already satisfied: idna>=2.8 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-core->jupyterlab<5,>=4.0.0->jupyterlab-vim) (3.10.0)
# Requirement already satisfied: referencing in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.30.2)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.1.4)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (4.19.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (6.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.10.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (23.1.0)
# Requirement already satisfied: webcolors>=1.11 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.13)
# Requirement already satisfied: uri-template in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.3.0)
# Requirement already satisfied: fqdn in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.5.1)
# Requirement already satisfied: isoduration in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.4)
# Requirement already satisfied: babel>=2.10 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.9.14)
# Requirement already satisfied: requests>=2.28 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.31.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (3.0.1)
# Requirement already satisfied: tinycss2 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.2.1)
# Requirement already satisfied: defusedxml in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (4.12.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.8.0)
# Requirement already satisfied: bleach!=5.0.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.16.1)
# Requirement already satisfied: six>=1.9.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.16.0)
# Requirement already satisfied: webencodings in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.5.1)
# Requirement already satisfied: fastjsonschema in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.19.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.19.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.19.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2023.7.22)
# Requirement already satisfied: ptyprocess in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.15.1)
# Requirement already satisfied: pycparser in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (8.15.0)
# Requirement already satisfied: comm>=0.1.1 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.6.7.post1)
# Requirement already satisfied: psutil in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (5.9.5)
# Requirement already satisfied: nest-asyncio in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.5.7)
# Requirement already satisfied: stack-data in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.6.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (3.0.39)
# Requirement already satisfied: jedi>=0.16 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.19.0)
# Requirement already satisfied: pexpect>4.3 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (4.8.0)
# Requirement already satisfied: pickleshare in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.7.5)
# Requirement already satisfied: decorator in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (5.1.1)
# Requirement already satisfied: backcall in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.8.3)
# Requirement already satisfied: wcwidth in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.2.6)
# Requirement already satisfied: arrow>=0.15.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (1.2.0)
# Requirement already satisfied: pure-eval in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0->jupyterlab-vim) (2.4.0)
# Installing collected packages: jupyterlab-vim
# Successfully installed jupyterlab-vim-4.0.3
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/gretar/Git/LEARNING/Statistical_rethinking/python-version/env/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# #### Code 2.1

# %%
ways = np.array([0, 3, 8, 9, 0])
ways / ways.sum()
# Out:
# array([0.  , 0.15, 0.4 , 0.45, 0.  ])

# %% [markdown]
# #### Code 2.2
#
# $$Pr(w \mid n, p) =  \frac{n!}{w!(n − w)!} p^w (1 − p)^{n−w}$$
#
#
# The probability of observing six W’s in nine tosses — below a value of $p=0.5$.

# %%
stats.binom.pmf(6, n=9, p=0.5)
# Out:
# 0.16406250000000003

# %% [markdown]
# #### Code 2.3 and 2.5
#
# Computing the posterior using a grid approximation.
#
# In the book, the following code is not inside a function, but this way it is easier to play with different parameters.

# %%
def uniform_prior(grid_points):
    """
    Returns Uniform prior density

            Parameters:
                grid_points (numpy.array): Array of prior values

            Returns:
                density (numpy.array): Uniform density of prior values
    """
    return np.repeat(5, grid_points)


def truncated_prior(grid_points, trunc_point=0.5):
    """
    Returns Truncated prior density

            Parameters:
                grid_points (numpy.array): Array of prior values
                trunc_point (double): Value where the prior is truncated

            Returns:
                density (numpy.array): Truncated density of prior values
    """
    return (np.linspace(0, 1, grid_points) >= trunc_point).astype(int)


def double_exp_prior(grid_points):
    """
    Returns Double Exponential prior density
Kenny Drews Vej 25, Copenhagen
            Parameters:
                grid_points (numpy.array): Array of prior values

            Returns:
                density (numpy.array): Double Exponential density of prior values
    """
    return np.exp(-5 * abs(np.linspace(0, 1, grid_points) - 0.5))

# %%
def binom_post_grid_approx(prior_func, grid_points=5, success=6, tosses=9):
    """
    Returns the grid approximation of posterior distribution with binomial likelihood.

            Parameters:
                    prior_func (function): A function that returns the likelihood of the prior
                    grid_points (int): Number of points in the prior grid
                    successes (int): Number of successes
                    tosses (int): number of tosses

            Returns:
                    p_grid (numpy.array): Array of prior values
                    posterior (numpy.array): Likelihood (density) of prior values
    """
    # define grid
    p_grid = np.linspace(0, 1, grid_points)

    # define prior
    prior = prior_func(grid_points)

    # compute likelihood at each point in the grid
    likelihood = stats.binom.pmf(success, tosses, p_grid)

    # compute product of likelihood and prior
    unstd_posterior = likelihood * prior

    # standardize the posterior, so it sums to 1
    posterior = unstd_posterior / unstd_posterior.sum()
    return p_grid, posterior

# %%
p_grid = np.linspace(0, 1, 20)
p_grid
# Out:
# array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ])

# %% [markdown]
# #### Code 2.3

# %%
w, n = 6, 9

points = (5, 20, 100)

_, ax = plt.subplots(1, len(points), figsize=(6 * len(points), 5))
for idx, ps in enumerate(points):
    p_grid, posterior = binom_post_grid_approx(uniform_prior, ps, w, n)
    ax[idx].plot(p_grid, posterior, "o-", label=f"successes = {w}\ntosses = {n}")
    ax[idx].set_xlabel("probability of water")
    ax[idx].set_ylabel("posterior probability")
    ax[idx].set_title(f"{ps} points")
    ax[idx].legend(loc=0)

# %%
_, ax = plt.subplots(1, len(points), figsize=(6 * len(points), 5))
for idx, ps in enumerate(points):
    p_grid, posterior = binom_post_grid_approx(truncated_prior, ps, w, n)
    ax[idx].plot(p_grid, posterior, "o-", label=f"successes = {w}\ntosses = {n}")
    ax[idx].set_xlabel("probability of water")
    ax[idx].set_ylabel("posterior probability")
    ax[idx].set_title(f"{ps} points")
    ax[idx].legend(loc=0)

# %%
_, ax = plt.subplots(1, len(points), figsize=(6 * len(points), 5))
for idx, ps in enumerate(points):
    p_grid, posterior = binom_post_grid_approx(double_exp_prior, ps, w, n)
    ax[idx].plot(p_grid, posterior, "o-", label=f"successes = {w}\ntosses = {n}")
    ax[idx].set_xlabel("probability of water")
    ax[idx].set_ylabel("posterior probability")
    ax[idx].set_title(f"{ps} points")
    ax[idx].legend(loc=0)

# %% [markdown]
# #### Code 2.6
#
# Computing the posterior using the quadratic approximation (quad).

# %%
np.repeat((0, 1), (3, 6))
# Out:
# array([0, 0, 0, 1, 1, 1, 1, 1, 1])

# %%
data = np.repeat((0, 1), (3, 6))
with pm.Model() as normal_approximation:
    p = pm.Uniform("p", 0, 1)  # uniform priors
    w = pm.Binomial("w", n=len(data), p=p, observed=data.sum())  # binomial likelihood
    mean_q = pm.find_MAP()

    p_value = normal_approximation.rvs_to_values[p]
    p_value.tag.transform = None
    p_value.name = p.name

    std_q = ((1 / pm.find_hessian(mean_q, vars=[p])) ** 0.5)[0]

# display summary of quadratic approximation
print("Mean, Standard deviation\np {:.2}, {:.2}".format(mean_q["p"], std_q[0]))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 00:00&lt;00:00 logp = -1.8075, ||grad|| = 1.5]
#     </div>
# Mean, Standard deviation
# p 0.67, 0.64

# %%
# Compute the 89% percentile interval
norm = stats.norm(mean_q, std_q)
prob = 0.89
z = stats.norm.ppf([(1 - prob) / 2, (1 + prob) / 2])
pi = mean_q["p"] + std_q * z
print("5.5%, 94.5% \n{:.2}, {:.2}".format(pi[0], pi[1]))
# Out:
# 5.5%, 94.5%
# -0.35, 1.7

# %% [markdown]
# #### Code 2.7

# %%
# analytical calculation
w, n = 6, 9
x = np.linspace(0, 1, 100)
plt.plot(x, stats.beta.pdf(x, w + 1, n - w + 1), label="True posterior")

# quadratic approximation
plt.plot(x, stats.norm.pdf(x, mean_q["p"], std_q), label="Quadratic approximation")
plt.legend(loc=0)

plt.title(f"n = {n}")
plt.xlabel("Proportion water");

# %%
# Figure 2.8
x = np.linspace(0, 1, 100)
w, n = [6, 12, 24], [9, 18, 36]

fig, ax = plt.subplots(1, 3, figsize=(21, 7))

for idx, ps in enumerate(zip(w, n)):
    data = np.repeat((0, 1), (ps[1] - ps[0], ps[0]))
    with pm.Model() as normal_approximation:
        p = pm.Uniform("p", 0, 1)  # uniform priors
        w = pm.Binomial("w", n=len(data), p=p, observed=data.sum())  # binomial likelihood
        mean_q = pm.find_MAP()

        p_value = normal_approximation.rvs_to_values[p]
        p_value.tag.transform = None
        p_value.name = p.name

        std_q = ((1 / pm.find_hessian(mean_q, vars=[p])) ** 0.5)[0]

    ax[idx].plot(x, stats.beta.pdf(x, ps[0] + 1, ps[1] - ps[0] + 1), label="True posterior")
    ax[idx].plot(x, stats.norm.pdf(x, mean_q["p"], std_q), label="Quadratic approximation")
    ax[idx].set_xlabel("probability of water")
    ax[idx].set_ylabel("density")
    ax[idx].set_title(r"$n={}$".format(ps[1]))
    ax[idx].legend(loc="upper left")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 00:00&lt;00:00 logp = -1.8075, ||grad|| = 1.5]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 00:00&lt;00:00 logp = -2.6477, ||grad|| = 3]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 00:00&lt;00:00 logp = -4.0055, ||grad|| = 6]
#     </div>

# %% [markdown]
# #### Code 2.8

# %%
n_samples = 1000
p = np.zeros(n_samples)
p[0] = 0.5
W = 6
L = 3
for i in range(1, n_samples):
    p_new = stats.norm(p[i - 1], 0.1).rvs(1)
    if p_new < 0:
        p_new = -p_new
    if p_new > 1:
        p_new = 2 - p_new
    q0 = stats.binom.pmf(W, n=W + L, p=p[i - 1])
    q1 = stats.binom.pmf(W, n=W + L, p=p_new)
    if stats.uniform.rvs(0, 1) < q1 / q0:
        p[i] = p_new
    else:
        p[i] = p[i - 1]
# Out:
# /tmp/ipykernel_514793/2095677985.py:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   p[i] = p_new

# %%
az.plot_kde(p, label="Metropolis approximation")
x = np.linspace(0, 1, 100)
plt.plot(x, stats.beta.pdf(x, W + 1, L + 1), "C1", label="True posterior")
plt.legend();

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w -p aesara,aeppl,xarray
# Out:
# Last updated: Tue Sep 05 2023
#
# Python implementation: CPython
# Python version       : 3.10.0
# IPython version      : 8.15.0
#
# aesara: not installed
# aeppl : not installed
# xarray: 2023.8.0
#
# arviz     : 0.16.1
# pymc      : 5.8.0
# scipy     : 1.11.2
# matplotlib: 3.7.2
# numpy     : 1.25.2
#
# Watermark: 2.4.3
